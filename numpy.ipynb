# %% [markdown]
# <a href="https://colab.research.google.com/github/sm1118sm/Data_Analysis/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#파일을 불러오되 꽃받침길이, 꽃받침넓이, 꽃잎길이 컬럼만 불러온 후 첫 번째 행부터 10건을 추출하여 출력하세요

import numpy as np
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = np.loadtxt(file_name, delimiter=',', skiprows=1, usecols=[0,1,2], encoding='cp949')
data2 = file1[0:10]
array3 = np.array(data2)
array3
# Out:
#      <input type="file" id="files-3e4e6c87-8c15-491b-b0d7-11a178f24026" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e4e6c87-8c15-491b-b0d7-11a178f24026">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#파일 2개를 불러와서 각각의 변수에 저장 후 하나의 행렬로 만들고 첫 번째 행부터 10건을 출력하세요 총 행수와 컬럼수를 출력하세요.

import numpy as np
from google.colab import files
uploaded = files.upload()
uploaded2 = files.upload()
file_name = list(uploaded.keys())[0]
file_name2 = list(uploaded2.keys())[0]
file1 = np.loadtxt(file_name, delimiter=',', skiprows=1, encoding='cp949')
file2 = np.loadtxt(file_name2, delimiter=',', skiprows=1, encoding='cp949')
data2 = file1[:]
data3 = file2[:]
array3 = np.array(data2)
array4 = np.array(data3)
array5 = np.hstack([array3, array4])
print(array5[0:10])
print()
print(array5.shape)
# Out:
#      <input type="file" id="files-96cf033e-27c3-4815-9b20-937ee984be10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96cf033e-27c3-4815-9b20-937ee984be10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')
plt.plot([1,2,3,4], [4,9,3,15])
plt.xlim(0,5)
plt.ylim(0,20)
plt.figure(figsize=(6,4))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name, encoding='cp949')
plt.style.use('ggplot')
x = df['년도']
y = df['콜레라']
plt.plot(x,y)
plt.show()
# Out:
#      <input type="file" id="files-392baabd-9254-4f64-b323-2425d920974f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-392baabd-9254-4f64-b323-2425d920974f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
df = pd.read_excel(file_name, skiprows=3)
display(df)
x = df['신청날짜']
y = df['수량']
plt.style.use('ggplot')
plt.plot(x,y)
plt.show()
# Out:
#      <input type="file" id="files-1b53c1a0-6dec-4cd2-942f-ac3d9b31ad9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b53c1a0-6dec-4cd2-942f-ac3d9b31ad9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
