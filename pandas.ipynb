# %% [markdown]
# <a href="https://colab.research.google.com/github/sm1118sm/DA/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#구글 코랩에서 Pandas를 사용하여 주어진 fish.csv 파일을 불러온 후 가장 앞의 5건을 출력한 후 총 행수와 컬럼의 개수를 출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
print(file1.head(5))
print(file1.shape)
# Out:
#      <input type="file" id="files-c255874c-bad0-4cbc-bd1b-ee67c75c6fae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c255874c-bad0-4cbc-bd1b-ee67c75c6fae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#구글 코랩에서 pandas를 사용하여 주어진 연습_부품구입대장.xlsx 파일을 불러온 후 가장 앞의 5건을 출력하고 총 건수와 컬럼 개수를 출력한 후 컬럼 이름을 모두  출력하세요

import pandas as pd
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_excel(file_name)
print(file1.head(5))
print(file1.shape)
print(file1.columns)
# Out:
#      <input type="file" id="files-21d2f915-f736-43f3-8091-dd0da8aea12e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21d2f915-f736-43f3-8091-dd0da8aea12e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
file1.loc[(file1['선수명'].str.contains('김')) & (file1['홈런'].between(20,50, inclusive ='left'))]
# Out:
#      <input type="file" id="files-5b61e6bd-8317-44ce-a7c1-f7aa756d17f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b61e6bd-8317-44ce-a7c1-f7aa756d17f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
