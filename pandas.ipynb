# %% [markdown]
# <a href="https://colab.research.google.com/github/sm1118sm/Data_Analysis/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#구글 코랩에서 Pandas를 사용하여 주어진 fish.csv 파일을 불러온 후 가장 앞의 5건을 출력한 후 총 행수와 컬럼의 개수를 출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
display(file1.head(5))
print(file1.shape)
# Out:
#      <input type="file" id="files-697de405-bed4-4e44-9c59-220d35f1b723" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-697de405-bed4-4e44-9c59-220d35f1b723">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#구글 코랩에서 pandas를 사용하여 주어진 연습_부품구입대장.xlsx 파일을 불러온 후 가장 앞의 5건을 출력하고 총 건수와 컬럼 개수를 출력한 후 컬럼 이름을 모두  출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_excel(file_name)
display(file1.head(5))
print(f"총건수와 컬럼수: {file1.shape}")
print(file1.columns)
# Out:
#      <input type="file" id="files-b0eb106a-38b3-47df-87f8-bc27c31621f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0eb106a-38b3-47df-87f8-bc27c31621f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_excel(file_name, skiprows = 3)
file1[['사업장', '품목', '수량', '금액']].head(6)
# Out:
#      <input type="file" id="files-9c14fc8c-2f36-4b08-b376-95bde6d595fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c14fc8c-2f36-4b08-b376-95bde6d595fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
file1[['선수이름', '포지션', '리바운드성공횟수']].head()
# Out:
#      <input type="file" id="files-8682d32a-ae6b-459c-823f-e31782f093db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8682d32a-ae6b-459c-823f-e31782f093db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1.filter(regex = '평균$')
# Out:
#      <input type="file" id="files-95f838e2-2b71-471c-8d95-069dd0024195" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95f838e2-2b71-471c-8d95-069dd0024195">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1[file1.columns.difference(['target'])]
# Out:
#      <input type="file" id="files-b1e554e7-39e6-4d05-b555-ceba32fa99bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1e554e7-39e6-4d05-b555-ceba32fa99bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#선수명에 '김'이 포함된 선수 중 홈런수가 20개 이상 50개 미만인 선수 조회하기

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
file1.loc[(file1['선수명'].str.contains('김')) & (file1['홈런'].between(20,50, inclusive ='left'))]
# Out:
#      <input type="file" id="files-5b61e6bd-8317-44ce-a7c1-f7aa756d17f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b61e6bd-8317-44ce-a7c1-f7aa756d17f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
file1.loc[(file1['선수명'].str.contains('김')) & (file1['홈런'].between(20,50, inclusive ='left')), ['선수명', '팀코드', '홈런']]
# Out:
#      <input type="file" id="files-b8c3ded3-bb3d-4357-b3fc-fe1ac7423b55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8c3ded3-bb3d-4357-b3fc-fe1ac7423b55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1[['메세지','발생시간','정지시간2','작업구분']].head(10)
# Out:
#      <input type="file" id="files-74197a92-f170-4073-8d15-16e2e3fc15f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74197a92-f170-4073-8d15-16e2e3fc15f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1.loc[(file1['작업자'].isin(['홍길동'])) & (file1['정지시간2'].between(30,100, inclusive = 'left')), ['메세지','발생시간','정지시간2','작업구분','작업자']]
# Out:
#      <input type="file" id="files-6ef78712-1dad-4ffd-8f43-94c56877f6d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ef78712-1dad-4ffd-8f43-94c56877f6d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#주어진 파일 2개를 구글 코랩에서 불러온 후 각각 data1, data2 변수에 저장하세요. 그 후 파일 2개를 merge 작업을 수행하여 data3 변수에 저장하세요. 그 후 data3에서 판매번호, 제품명, 판매수량, 컬럼만 출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
uploaded2 = files.upload()
file_name = list(uploaded.keys())[0]
file_name2 = list(uploaded2.keys())[0]
data1 = pd.read_csv(file_name, encoding = 'CP949')
data2 = pd.read_csv(file_name2, encoding = 'CP949')
data3 = pd.merge(data1, data2, left_on = '제품ID', right_on = 'ID', how = 'outer')
data3[['판매번호', '제품명', '판매수량']]
# Out:
#      <input type="file" id="files-415a2d7e-bd24-415e-933c-38d875fe90a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-415a2d7e-bd24-415e-933c-38d875fe90a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#파일을 불러와서 메세지, 발생시간, 정지시간2, 작업구분 컬럼을 추출하되 정지시간2 값이 높은 순서대로 10건만 출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1.sort_values('정지시간2', ascending = False)[['메세지', '발생시간', '정지시간2', '작업구분']].head(10)
# Out:
#      <input type="file" id="files-e7c5b46d-1504-4ca3-82e4-5d378a27f991" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7c5b46d-1504-4ca3-82e4-5d378a27f991">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file2 = file1.groupby(['팀명'], as_index=False)['홈런'].sum()
file2.sort_values('홈런', ascending = False)
# Out:
#      <input type="file" id="files-129af591-2c6f-4423-bccd-5f35d1c40c69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-129af591-2c6f-4423-bccd-5f35d1c40c69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
file2 = file1.groupby(['사업장','품목'], as_index = False)['수량'].sum()
file2.sort_values(['수량', '사업장'], ascending = [False, True]).head(10)
# Out:
#      <input type="file" id="files-bd38db9c-56fb-425f-a9b9-a67e09d7e1be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd38db9c-56fb-425f-a9b9-a67e09d7e1be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name, encoding = 'CP949')
file2 = file1.groupby(['사업장','품목'], as_index = False)['수량'].sum()
file2[file2['사업장'].isin(['석수'])].sort_values(['수량'], ascending = False).head(10)
# Out:
#      <input type="file" id="files-1d081f5c-5c31-4a4f-91b9-cd68e1a921fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d081f5c-5c31-4a4f-91b9-cd68e1a921fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file2 = file1.groupby(['메세지'], as_index = False)['정지시간2'].sum()
file2.sort_values(['정지시간2'], ascending = False).head(10)
# Out:
#      <input type="file" id="files-25448b51-0274-465b-b602-9e0e6e092b53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25448b51-0274-465b-b602-9e0e6e092b53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1.groupby([''])

# %%
#파일을 활용하여 오류 메세지별 정지시간2 컬럼 값의 총합을 구한 후 정지시간2 값이 높은 순서부터 출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_csv(file_name)
file1.groupby('메세지', as_index = False)['정지시간2'].sum().sort_values('정지시간2', ascending = False).head(10)
# Out:
#      <input type="file" id="files-22e88fd7-8d82-464e-bd75-ef02fb288867" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22e88fd7-8d82-464e-bd75-ef02fb288867">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#파일을 부러온 후 팀명을 기준으로 득점과 홈런의 sum과 mean 값을 구해서 출력하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_excel(file_name)
data = pd.pivot_table(file1, index = '팀명', values = ['득점', '홈런'], aggfunc = ['sum', 'mean'])
data.sort_values(('sum','홈런'), ascending = False)
# Out:
#      <input type="file" id="files-798c5a22-e96d-48bf-8b49-f963a2363436" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-798c5a22-e96d-48bf-8b49-f963a2363436">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#앞의 문제에서 mean의 홈런 개수가 20개 이상 50개 이하인 값만 추출한 후 mean 홈런 값이 큰 수부터 먼저 출력되도록 정렬하세요

import pandas as pd
from google.colab import files
uploaded = files.upload()
file_name = list(uploaded.keys())[0]
file1 = pd.read_excel(file_name)
data = pd.pivot_table(file1, index = '팀명', values = ['득점', '홈런'], aggfunc = ['sum', 'mean'])
data2 = data.loc[(data['mean']['홈런'] >= 20) & (data['mean']['홈런'] <= 50)]
data2.sort_values(('mean', '홈런'), ascending = False)
# Out:
#      <input type="file" id="files-21aaa0c4-7b7e-4420-9068-6d3a26684860" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21aaa0c4-7b7e-4420-9068-6d3a26684860">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
